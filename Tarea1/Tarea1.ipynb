# %% [markdown]
# <img src="logo_uach.png" alt="UACh" style="height: 200px; display: block;margin-left: auto;margin-right: auto;"/>
#
# # Tarea 1: Instalación Software ACUS099
# ## Integrantes:
# + Joaquin Toledo
# + Cristóbal González

# %% [markdown]
# # Uso de Markdown
# ## Introducción
# ## Fundamentos
# Instalación (miniconda)
# ### Índice
# + Introducción
# + **Ecuaciones en LaTeX** \
#   $a^2+b^2=c^2$
#   $$x(t)=Asin(\omega t+\phi)$$
#   \begin{equation}
#     f(x) = \int_{-\infty}^{\infty} e^{-x^2} dx
#   \end{equation}
# **Negrita** y *Cursiva*
#
# + Enlaces
#   > En el siguente [Link UACh](https://uach.cl/)
# + hola
# ~~~
# ipykernel
# ~~~

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('1R0ZUeRuPfk', width=800, height=400)
